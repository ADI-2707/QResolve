# %%
import pandas as pd
import matplotlib.pyplot as plt

from src.data_loader import load_csv
from src.data_validator import validate_dataframe

# %%
df = load_csv("../data/raw/customer_support_tickets.csv")

validate_dataframe(df)

print(df.shape)
df.head()
# Out:
# 2026-07-04 11:07:55,783 | INFO | src.data_loader | Loading dataset: ..\data\raw\customer_support_tickets.csv
# 2026-07-04 11:07:55,814 | INFO | src.data_loader | Dataset loaded successfully (8469 rows, 17 columns)
# 2026-07-04 11:07:55,815 | INFO | src.data_validator | Starting dataset validation.
# 2026-07-04 11:07:55,815 | ERROR | src.data_validator | Missing required columns: ['ticket_id', 'subject', 'description', 'priority', 'department']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 df = load_csv("../data/raw/customer_support_tickets.csv")
#       2
# ----> 3 validate_dataframe(df)
#       4
#       5 print(df.shape)
#       6 df.head()
#
# File ~\Desktop\QResolve\src\data_validator.py:155, in validate_dataframe(dataframe)
#     149 """
#     150 Run all validation checks on the dataset.
#     151 """
#     153 logger.info("Starting dataset validation.")
# --> 155 validate_columns(dataframe)
#     156 validate_missing_values(dataframe)
#     157 validate_duplicate_ticket_ids(dataframe)
#
# File ~\Desktop\QResolve\src\data_validator.py:47, in validate_columns(dataframe, required_columns)
#      45 if missing_columns:
#      46     logger.error("Missing required columns: %s", missing_columns)
# ---> 47     raise ValueError(
#      48         f"Missing required columns: {missing_columns}"
#      49     )
#      51 logger.info("All required columns are present.")
#
# ValueError: Missing required columns: ['ticket_id', 'subject', 'description', 'priority', 'department']

# %%
df.columns.tolist()

# %%
df = load_csv("../data/raw/customer_support_tickets.csv")

validate_dataframe(df)

print(df.shape)

df.head()

# %%
import pandas as pd

from src.data_loader import load_csv
from src.data_validator import validate_dataframe

# %%
df = load_csv("../data/raw/customer_support_tickets.csv")

validate_dataframe(df)

print(df.shape)
df.head()
# Out:
# 2026-07-04 11:08:07,984 | INFO | src.data_loader | Loading dataset: ..\data\raw\customer_support_tickets.csv
# 2026-07-04 11:08:08,016 | INFO | src.data_loader | Dataset loaded successfully (8469 rows, 17 columns)
# 2026-07-04 11:08:08,016 | INFO | src.data_validator | Starting dataset validation.
# 2026-07-04 11:08:08,017 | ERROR | src.data_validator | Missing required columns: ['ticket_id', 'subject', 'description', 'priority', 'department']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 df = load_csv("../data/raw/customer_support_tickets.csv")
#       2
# ----> 3 validate_dataframe(df)
#       4
#       5 print(df.shape)
#       6 df.head()
#
# File ~\Desktop\QResolve\src\data_validator.py:155, in validate_dataframe(dataframe)
#     149 """
#     150 Run all validation checks on the dataset.
#     151 """
#     153 logger.info("Starting dataset validation.")
# --> 155 validate_columns(dataframe)
#     156 validate_missing_values(dataframe)
#     157 validate_duplicate_ticket_ids(dataframe)
#
# File ~\Desktop\QResolve\src\data_validator.py:47, in validate_columns(dataframe, required_columns)
#      45 if missing_columns:
#      46     logger.error("Missing required columns: %s", missing_columns)
# ---> 47     raise ValueError(
#      48         f"Missing required columns: {missing_columns}"
#      49     )
#      51 logger.info("All required columns are present.")
#
# ValueError: Missing required columns: ['ticket_id', 'subject', 'description', 'priority', 'department']

# %%
import src.data_validator

print(src.data_validator.__file__)
# Out:
# C:\Users\User\Desktop\QResolve\src\data_validator.py

# %%
import inspect
import src.data_validator

print(inspect.getsource(src.data_validator.validate_columns))
# Out:
# from typing import Iterable
#
# import pandas as pd
#
# from src.logger import get_logger
#
# logger = get_logger(__name__)
#
# REQUIRED_COLUMNS = [
#     "Ticket ID",
#     "Ticket Subject",
#     "Ticket Description",
#     "Ticket Priority",
#     "Ticket Type",
#     "Ticket Status",
# ]
#
# VALID_PRIORITIES = {
#     "High",
#     "Medium",
#     "Low",
# }
#
# VALID_TICKET_TYPES = {
#     "Technical issue",
#     "Billing inquiry",
#     "Cancellation request",
#     "Product inquiry",
#     "Refund request",
# }
#
# VALID_STATUSES = {
#     "Open",
#     "Closed",
#     "Pending",
# }
#
#
# def validate_columns(
#     dataframe: pd.DataFrame,
#     required_columns: Iterable[str] = REQUIRED_COLUMNS,
# ) -> None:
#     """
#     Validate that all required columns exist.
#     """
#
#     missing_columns = [
#         column
#         for column in required_columns
#         if column not in dataframe.columns
#     ]
#
#     if missing_columns:
#         logger.error("Missing required columns: %s", missing_columns)
#         raise ValueError(
#             f"Missing required columns: {missing_columns}"
#         )
#
#     logger.info("All required columns are present.")

# %%
import inspect
import src.data_validator

print(inspect.getsource(src.data_validator.validate_columns))
# Out:
# def validate_columns(
#     dataframe: pd.DataFrame,
#     required_columns: Iterable[str] = REQUIRED_COLUMNS,
# ) -> None:
#     """
#     Validate that all required columns exist.
#     """
#
#     missing_columns = [
#         column
#         for column in required_columns
#         if column not in dataframe.columns
#     ]
#
#     if missing_columns:
#         logger.error("Missing required columns: %s", missing_columns)
#         raise ValueError(
#             f"Missing required columns: {missing_columns}"
#         )
#
#     logger.info("All required columns are present.")

# %%
import src.data_validator

print(src.data_validator.REQUIRED_COLUMNS)
# Out:
# ['Ticket ID', 'Ticket Subject', 'Ticket Description', 'Ticket Priority', 'Ticket Type', 'Ticket Status']

# %%
print(df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(df.columns.tolist())
#
# NameError: name 'df' is not defined

# %%
from src.data_loader import load_csv

df = load_csv("../data/raw/customer_support_tickets.csv")

print(df.columns.tolist())
# Out:
# 2026-07-04 11:13:15,788 | INFO | src.data_loader | Loading dataset: ..\data\raw\customer_support_tickets.csv
# 2026-07-04 11:13:15,821 | INFO | src.data_loader | Dataset loaded successfully (8469 rows, 17 columns)
# ['Ticket ID', 'Customer Name', 'Customer Email', 'Customer Age', 'Customer Gender', 'Product Purchased', 'Date of Purchase', 'Ticket Type', 'Ticket Subject', 'Ticket Description', 'Ticket Status', 'Resolution', 'Ticket Priority', 'Ticket Channel', 'First Response Time', 'Time to Resolution', 'Customer Satisfaction Rating']

# %%
validate_dataframe(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 validate_dataframe(df)
#
# NameError: name 'validate_dataframe' is not defined

# %%
from src.data_loader import load_csv
from src.data_validator import validate_dataframe

df = load_csv("../data/raw/customer_support_tickets.csv")

validate_dataframe(df)
# Out:
# 2026-07-04 11:20:18,725 | INFO | src.data_loader | Loading dataset: ..\data\raw\customer_support_tickets.csv
# 2026-07-04 11:20:18,761 | INFO | src.data_loader | Dataset loaded successfully (8469 rows, 17 columns)
# 2026-07-04 11:20:18,762 | INFO | src.data_validator | Starting dataset validation.
# 2026-07-04 11:20:18,762 | INFO | src.data_validator | All required columns are present.
# 2026-07-04 11:20:18,765 | INFO | src.data_validator | No missing values found.
# 2026-07-04 11:20:18,765 | INFO | src.data_validator | No duplicate Ticket IDs found.
# 2026-07-04 11:20:18,766 | INFO | src.data_validator | Priority values are valid.
# 2026-07-04 11:20:18,767 | INFO | src.data_validator | Ticket types are valid.
# 2026-07-04 11:20:18,769 | ERROR | src.data_validator | Invalid status values: ['Pending Customer Response']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       2 from src.data_validator import validate_dataframe
#       3
#       4 df = load_csv("../data/raw/customer_support_tickets.csv")
#       5
# ----> 6 validate_dataframe(df)
#
# File ~\Desktop\QResolve\src\data_validator.py:203, in validate_dataframe(dataframe)
#     201 validate_priority_values(dataframe)
#     202 validate_ticket_type_values(dataframe)
# --> 203 validate_status_values(dataframe)
#     205 logger.info("Dataset validation completed successfully.")
#
# File ~\Desktop\QResolve\src\data_validator.py:184, in validate_status_values(dataframe)
#     178 if len(invalid) > 0:
#     179     logger.error(
#     180         "Invalid status values: %s",
#     181         list(invalid),
#     182     )
# --> 184     raise ValueError(
#     185         f"Invalid status values: {list(invalid)}"
#     186     )
#     188 logger.info("Ticket status values are valid.")
#
# ValueError: Invalid status values: ['Pending Customer Response']

# %%
print(df["Ticket Priority"].unique())
# Out:
# ['Critical' 'Low' 'High' 'Medium']

# %%
from src.data_loader import load_csv
from src.data_validator import validate_dataframe
df = load_csv("../data/raw/customer_support_tickets.csv")
validate_dataframe(df)
# Out:
# 2026-07-04 11:21:12,635 | INFO | src.data_loader | Loading dataset: ..\data\raw\customer_support_tickets.csv
# 2026-07-04 11:21:12,670 | INFO | src.data_loader | Dataset loaded successfully (8469 rows, 17 columns)
# 2026-07-04 11:21:12,672 | INFO | src.data_validator | Starting dataset validation.
# 2026-07-04 11:21:12,672 | INFO | src.data_validator | All required columns are present.
# 2026-07-04 11:21:12,675 | INFO | src.data_validator | No missing values found.
# 2026-07-04 11:21:12,675 | INFO | src.data_validator | No duplicate Ticket IDs found.
# 2026-07-04 11:21:12,676 | INFO | src.data_validator | Priority values are valid.
# 2026-07-04 11:21:12,677 | INFO | src.data_validator | Ticket types are valid.
# 2026-07-04 11:21:12,678 | ERROR | src.data_validator | Invalid status values: ['Pending Customer Response']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 from src.data_loader import load_csv
#       2 from src.data_validator import validate_dataframe
#       3 df = load_csv("../data/raw/customer_support_tickets.csv")
# ----> 4 validate_dataframe(df)
#
# File ~\Desktop\QResolve\src\data_validator.py:203, in validate_dataframe(dataframe)
#     201 validate_priority_values(dataframe)
#     202 validate_ticket_type_values(dataframe)
# --> 203 validate_status_values(dataframe)
#     205 logger.info("Dataset validation completed successfully.")
#
# File ~\Desktop\QResolve\src\data_validator.py:184, in validate_status_values(dataframe)
#     178 if len(invalid) > 0:
#     179     logger.error(
#     180         "Invalid status values: %s",
#     181         list(invalid),
#     182     )
# --> 184     raise ValueError(
#     185         f"Invalid status values: {list(invalid)}"
#     186     )
#     188 logger.info("Ticket status values are valid.")
#
# ValueError: Invalid status values: ['Pending Customer Response']

# %%
from src.data_loader import load_csv
from src.data_validator import validate_dataframe

df = load_csv("../data/raw/customer_support_tickets.csv")

validate_dataframe(df)
# Out:
# 2026-07-04 11:22:29,707 | INFO | src.data_loader | Loading dataset: ..\data\raw\customer_support_tickets.csv
# 2026-07-04 11:22:29,740 | INFO | src.data_loader | Dataset loaded successfully (8469 rows, 17 columns)
# 2026-07-04 11:22:29,740 | INFO | src.data_validator | Starting dataset validation.
# 2026-07-04 11:22:29,741 | INFO | src.data_validator | All required columns are present.
# 2026-07-04 11:22:29,743 | INFO | src.data_validator | No missing values found.
# 2026-07-04 11:22:29,744 | INFO | src.data_validator | No duplicate Ticket IDs found.
# 2026-07-04 11:22:29,745 | INFO | src.data_validator | Priority values are valid.
# 2026-07-04 11:22:29,746 | INFO | src.data_validator | Ticket types are valid.
# 2026-07-04 11:22:29,747 | INFO | src.data_validator | Ticket status values are valid.
# 2026-07-04 11:22:29,748 | INFO | src.data_validator | Dataset validation completed successfully.

# %%
print(df["Ticket Status"].unique())
# Out:
# ['Pending Customer Response' 'Closed' 'Open']

# %%
from src.data_loader import load_csv
from src.data_validator import validate_dataframe

df = load_csv("../data/raw/customer_support_tickets.csv")
validate_dataframe(df)

print("✅ Validation passed!")
# Out:
# 2026-07-04 11:24:42,122 | INFO | src.data_loader | Loading dataset: ..\data\raw\customer_support_tickets.csv
# 2026-07-04 11:24:42,156 | INFO | src.data_loader | Dataset loaded successfully (8469 rows, 17 columns)
# 2026-07-04 11:24:42,158 | INFO | src.data_validator | Starting dataset validation.
# 2026-07-04 11:24:42,158 | INFO | src.data_validator | All required columns are present.
# 2026-07-04 11:24:42,161 | INFO | src.data_validator | No missing values found.
# 2026-07-04 11:24:42,161 | INFO | src.data_validator | No duplicate Ticket IDs found.
# 2026-07-04 11:24:42,162 | INFO | src.data_validator | Priority values are valid.
# 2026-07-04 11:24:42,163 | INFO | src.data_validator | Ticket types are valid.
# 2026-07-04 11:24:42,164 | INFO | src.data_validator | Ticket status values are valid.
# 2026-07-04 11:24:42,164 | INFO | src.data_validator | Dataset validation completed successfully.
# ✅ Validation passed!
