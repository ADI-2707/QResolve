# %% [markdown]
# # Model Training
#
# Train machine learning models to predict customer satisfaction ratings using the processed dataset prepared during feature engineering.

# %%
import pandas as pd

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
)

# %% [markdown]
# # Load Processed Training and Testing Data
#
# Load the datasets generated during feature engineering.

# %%
X_train = pd.read_csv("../data/processed/X_train.csv")
X_test = pd.read_csv("../data/processed/X_test.csv")

y_train = pd.read_csv("../data/processed/y_train.csv")
y_test = pd.read_csv("../data/processed/y_test.csv")

# %%
print("Training Features:", X_train.shape)
print("Testing Features :", X_test.shape)

print("Training Labels :", y_train.shape)
print("Testing Labels  :", y_test.shape)
# Out:
# Training Features: (2215, 9)
# Testing Features : (554, 9)
# Training Labels : (2215, 1)
# Testing Labels  : (554, 1)

# %% [markdown]
# # Prepare Target Variables
#
# Convert the target datasets into one-dimensional arrays required by scikit-learn models.

# %%
y_train = y_train.squeeze()
y_test = y_test.squeeze()

# %%
print(type(y_train))
print(type(y_test))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # Train Baseline Model
#
# Train a Linear Regression model as the baseline for performance comparison.

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

linear_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 linear_model = LinearRegression()
#       2
# ----> 3 linear_model.fit(X_train, y_train)
#
# File ~\Desktop\QResolve\.venv\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File ~\Desktop\QResolve\.venv\Lib\site-packages\sklearn\linear_model\_base.py:618, in LinearRegression.fit(self, X, y, sample_weight)
#     614 n_jobs_ = self.n_jobs
#     616 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 618 X, y = validate_data(
# ...

# %%
X_train.dtypes
# Out:
# Ticket Subject        object
# Ticket Description    object
# Ticket Type            int64
# Ticket Priority        int64
# Ticket Channel         int64
# Customer Age           int64
# Customer Gender        int64
# Product Purchased      int64
# Ticket Text           object
# dtype: object
